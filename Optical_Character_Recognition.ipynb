# %% [markdown]
# <a href="https://colab.research.google.com/github/gokul-siva-krishna/optical-character-recognition/blob/main/Optical_Character_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
Image("/text1.png")

# %%
output = reader.readtext('/text1.png')
output
# Out:
# [([[165, 33], [361, 33], [361, 89], [165, 89]], 'SCENE', 0.7311117346922557),
#  ([[392, 30], [571, 30], [571, 90], [392, 90]], 'FROM', 0.997999370098114),
#  ([[598, 38], [630, 38], [630, 66], [598, 66]], '((', 0.7875017903400383),
#  ([[636, 32], [820, 32], [820, 84], [636, 84]], "DAN'L", 0.7055158900900187),
#  ([[850, 30], [1098, 30], [1098, 86], [850, 86]],
#   'DRUCE;"',
#   0.6825920183590382),
#  ([[59, 88], [901, 88], [901, 151], [59, 151]],
#   'Thig interesting domestic drama, by Mr.',
#   0.53931914538308),
#  ([[912, 88], [1205, 88], [1205, 144], [912, 144]],
#   'W . S. Gilbert,',
#   0.46871649304478646),
#  ([[58, 137], [350, 137], [350, 186], [58, 186]],
#   'hag continued',
#   0.7513117889647232),
#  ([[367, 143], [417, 143], [417, 183], [367, 183]], 'to', 0.9999758920877662),
#  ([[436, 129], [922, 129], [922, 198], [436, 198]],
#   'engage the   sympathies',
#   0.882940528123268),
#  ([[935, 137], [985, 137], [985, 181], [935, 181]], 'of', 0.5608343952185619),
# ...
